# %% [markdown]
# # CS013: Self-Driving Car Sim
#
# Pitch origin: CS032 (polymath-dream). Gated pipeline in `_nospace/cs013_work/`.

# %% [markdown]
# ## Status
#
# Scaffold stub — pipeline steps land results here.
